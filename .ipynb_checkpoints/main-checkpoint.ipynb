# %% [markdown]
# # **What is the relationship between specific post characteristics and the likelihood of a post achieving viral status on Social Media?**

# %% [markdown]
# # **Abstract**
#
# With viral posts frequently emerging on social media platforms, understanding the factors that contribute to their widespread popularity has become increasingly important for social media influencers or brand companies. This study explores the relationship between specific post characteristics and the likelihood of a post achieving viral status. By analysing features such as content attributes, format, and engagement metrics, we identify patterns associated with highly shared, liked or commented posts. The findings aim to provide insights into the mechanisms behind online virality and offer guidance for creating content with higher potential for widespread reach.

# %% [markdown]
# # **Table Of Contents**
#
# 1. [Key Terms & Definitions (Ask)](#1-key-terms--definitions-ask)
# 2. [Analysis Goal (Ask)](#2-analysis-goal-ask)
# 3. [Data Requirements Analysis (Prepare)](#3-data-requirements-analysis-prepare)
# 4. [Data Sources (Prepare)](#4-data-sources-prepare)
# 5. [Determing DS Suitability (Prepare)](#5-determing-ds-suitability-prepare)
# <!-- 6. [Data Preparation (Process)](#data-preparation-posts--reels--analytics)
# 7. [Data Analysis (Analyze)](#data-analysis-analyze) -->

# %% [markdown]
# # **1. Key Terms & Definitions (Ask)**

# %% [markdown]
# **Post characteristics**
#
# Post characteristics refer to measurable attributes of a social media post that may influence its popularity. These characteristics vary depending on the content format. For video posts, relevant features may include video duration, frame rate, and resolution. For text-based posts, relevant features may include text length, sentiment and tone. Additional attributes applicable across formats include posting time (hour of the day), day of the week, number of hashtags and creator status, to name a few.
#
# **Viral status**
#
# Viral status refers to a post achieving significantly higher visibility and engagement compared to typical posts on the same platform. Viral posts often exhibit rapid growth in engagement metrics, such as views, likes, comments, and shares, indicating a fast spread across users. This spread may extend beyond the post’s original audience or community. In cases where temporal engagement data is unavailable (growth rate of views against time for e.g.), virality will be determined using predefined thresholds within a fixed time frame. This can include reaching a specific number of views, shares, or likes that is equivalent to the engagement median times three, or the post is in the top 5% by engagement in its dataset.
#
# **Social Media**
#
# This study explores posts from TikTok and Instagram. These platforms are among the most widely used social media platform globally and provide diverse content formats such as short videos, images, and text-based posts, making them suitable platforms for analysing patterns of online virality.
#
# [Back to TOC](#table-of-contents)

# %% [markdown]
# # **2. Analysis Goal (Ask)**

# %% [markdown]
# The primary objective of this analysis is to determine how specific characteristics of social media posts influence their likelihood of achieving viral status. The main question to be asked in this study is: Which post characteristics are most strongly associated with viral posts on social media platforms?
#
# To address this research question, we first conduct exploratory data analysis to identify patterns in the characteristics of viral posts. Post characteristics such as content length, number of hashtags, posting time, and media properties are analysed to determine their relationship with virality. Using these insights, a predictive model is then developed to estimate the likelihood of a post becoming viral based on its attributes.
#
# The performance and usefulness of the analysis will be evaluated based on its ability to identify meaningful patterns and predictive features associated with viral content. Depending on the modelling approach used, evaluation metrics may include classification accuracy, precision, recall, or other relevant performance indicators.
#
# Stakeholders can then strategically incorporate such characteristics into their posts to increase the probability of making it viral.
#
# [Back to TOC](#table-of-contents)

# %% [markdown]
# # **3. Data Requirements Analysis (Prepare)**

# %% [markdown]
# To tackle the problem, several categories of data are required.
#
# First, post metadata is needed to provide contextual information about when and where a post was published. This includes the date and time of posting, the day of the week, the account used to publish the post, and the number of followers the account had at the time of posting.
#
# Second, engagement metrics are required to determine whether a post achieves viral status. These metrics include the number of likes or reactions, the number of shares, and the number of comments. Additional indicators such as reach or impressions, engagement rate (calculated as total engagement divided by the number of followers), and the growth rate of engagement within a specific timeframe may also be collected if available.
#
# Third, content characteristics describe the properties of the post itself. These include the content type (such as text-only, image, or video), video length, text length, and the number of images included in a post. Textual features may also be analysed, including caption length, the number of hashtags, mentions or tags, the presence of emojis, sentiment score (e.g., positive, negative, or neutral), and readability score. Where available, visual features such as image colorfulness or brightness, the presence of faces or people, thumbnail quality for videos, and audio-related information such as sound effects may also be considered.
#
# Finally, additional contextual information may be collected to further enrich the analysis. This includes the topic category of the post, which may help identify patterns related to content themes or audience characteristics.
#
# [Back to TOC](#table-of-contents)

# %% [markdown]
# # **4. Data Sources (Prepare)**

# %% [markdown]
# **List of considered data sources:**
#
# In the following, we outline several potential data sources that were explored for this project. Each source was evaluated for their suitability for analysing social media virality. The final selected data source is marked with an asterisk (*).
#
# **Instagram DS**
# 1. [DS1](#ds1---instagram-analytics) - Link: [Instagram Analytics](https://www.kaggle.com/datasets/kundanbedmutha/instagram-analytics-dataset) - `Instagram_Analytics.csv` *
# 2. [DS2](#ds2---instagram-posts) - Link: [Instagram Posts](https://brightdata.com/cp/datasets/browse/gd_lk5ns7kz21pck8jpis?id=hl_6c69a494) - `Instagram_Posts.csv` *
# 3. [DS3](#ds3---instagram-reels) - Link: [Instagram Reels](https://brightdata.com/cp/datasets/browse/gd_lyclm20il4r5helnj?id=hl_6c69a494) - `Instagram_Reels.csv` *
# 4. [DS4](#ds4---instagram-datasets) - Link: [Instagram Datasets](https://github.com/luminati-io/Social-media-dataset-samples) - `Instagram_Datasets.csv`
#
# **TikTok DS**
# 1. [DS5](#ds5---tiktok-posts) - Link: [TikTok Posts](https://huggingface.co/datasets/Shofo/shofo-tiktok-general-small) - `TikTok_Posts.csv` *
# 2. [DS6](#ds6---tiktok-texts) - Link: [TikTok Texts](https://huggingface.co/datasets/Shofo/shofo-tiktok-general-small) - `TikTok_Texts.csv` *
#
# These datasets were assessed based on their availability of engagement metrics, post metadata, and content features required for the analysis. The selected dataset (*) provides the most comprehensive set of variables needed to examine the relationship between post attributes and social media virality.
#
# [Back to TOC](#table-of-contents)

# %% [markdown]
# # **5. Determing DS Suitability (Prepare)**

# %% [markdown]
# ## **DS1 - Instagram Analytics**

# %% [markdown]
# ### Brief Description and Match to Requirements
# `Instagram_Analytics.csv` is a structured post-level dataset containing content features (`media_type`, `content_category`, `hashtags_count`, `caption_length`, `post_hour`, `day_of_week`), engagement outcomes (`likes`, `comments`, `shares`, `saves`, `reach`, `impressions`, `engagement_rate`), and a performance label (`performance_bucket_label`, including `viral` in sampled rows). This aligns strongly with our analytical task because it directly supports studying the relationship between post characteristics and viral outcomes.

# %% [markdown]
# ### Profiling Steps (Description + Code + Interpretation)
# **Step A - Structural profile (shape, dtypes, sample values)**
#
# ```python
# import pandas as pd
#
# df_analytics = pd.read_csv("datasets/raw/Instagram_Analytics.csv")
#
# print("Shape:", df_analytics.shape)
# print("\nDtypes:\n", df_analytics.dtypes)
# print("\nFirst rows:\n", df_analytics.head(3))
# ```
#
# **Interpretation:** This checks whether the dataset is tabular at post level and whether key columns are present with expected data types.
#
# **Step B - Missingness and duplicates**
#
# ```python
# print("\nMissing values:\n", df_analytics.isna().sum().sort_values(ascending=False))
# print("\nDuplicate post_id:", df_analytics["post_id"].duplicated().sum())
# ```
#
# **Interpretation:** Low missingness and minimal duplication improve reliability for modeling and inference.
#
# **Step C - Outcome and feature distribution sanity checks**
#
# ```python
# print(df_analytics["performance_bucket_label"].value_counts(dropna=False))
# print(df_analytics[["likes", "comments", "shares", "hashtags_count", "caption_length"]].describe())
# ```
#
# **Interpretation:** We verify target representation and inspect skew/outliers in engagement variables that may affect model and test choices.

# %% [markdown]
# ### Data Quality Discussion
# - **Positive criterion (Relevance/Completeness):** The dataset contains both explanatory post-characteristic variables and engagement/virality outcomes in one place, making it highly suitable for the main research question.
# - **Problematic criterion (Potential label leakage):** `performance_bucket_label` may be derived from engagement metrics (`likes`, `comments`, `shares`, etc.). If so, using the same engagement metrics as predictors for that label can cause leakage. We must document label construction and separate predictor/target design carefully.
#
# ### Concluding Suitability Statement
# This dataset is **highly suitable** and should be a primary source for the analytical phase. Key precautions are to verify how `performance_bucket_label` is defined, check class balance for `viral`, and prevent leakage by excluding features that directly define the target when building predictive models.
#
# [Back to DS](#4-data-sources-prepare)

# %% [markdown]
# ## **DS2 - Instagram Posts**
#
# ### Brief Description and Match to Requirements
# `Instagram_Posts.csv` is a post-level Instagram dataset with rich metadata (`description`, `hashtags`, `date_posted`, `content_type`, account and profile attributes) and core engagement fields (`likes`, `num_comments`). It is amenable to our task because it supports feature engineering on post characteristics, though virality must be derived since no explicit `viral` label is provided.

# %% [markdown]
# ### Profiling Steps (Description + Code + Interpretation)
# **Step A - Structural profile and key columns check**
#
# ```python
# import pandas as pd
#
# df_posts = pd.read_csv("datasets/raw/Instagram_Posts.csv")
#
# print("Shape:", df_posts.shape)
# print("Columns:", df_posts.columns.tolist())
# print(df_posts[["post_id", "date_posted", "likes", "num_comments", "hashtags"]].head(3))
# ```
#
# **Interpretation:** Confirms whether required fields for temporal, textual, and hashtag features are present.
#
# **Step B - Missingness and duplicates**
#
# ```python
# print("\nMissing values (top 15):\n", df_posts.isna().sum().sort_values(ascending=False).head(15))
# print("Duplicate post_id:", df_posts["post_id"].duplicated().sum())
# ```
#
# **Interpretation:** Identifies whether columns are usable directly or need imputation/filtering.
#
# **Step C - Numeric plausibility checks**
#
# ```python
# for col in ["likes", "num_comments", "followers", "video_view_count", "video_play_count"]:
#     if col in df_posts.columns:
#         print(col, "negatives:", (pd.to_numeric(df_posts[col], errors="coerce") < 0).sum())
# ```
#
# **Interpretation:** Negative engagement values are invalid and should be treated as data quality issues.

# %% [markdown]
# ### Data Quality Discussion
# - **Positive criterion (Feature richness):** Strong variety of post and account characteristics supports meaningful feature engineering (e.g., hashtag count, posting time, creator-level controls).
# - **Problematic criterion (Completeness consistency):** Several fields are sparse or format-inconsistent across rows (e.g., nested text/metadata fields, possible null-heavy account attributes). This requires careful column selection and standardized cleaning before analysis.
#
# ### Concluding Suitability Statement
# This dataset is **suitable with moderate preprocessing effort**. It is valuable for post-feature extraction and exploratory relationship testing, but requires robust cleaning and explicit virality definition (or linkage with labeled data) before predictive analysis.
#
# [Back to DS](#4-data-sources-prepare)

# %% [markdown]
# ## **DS3 - Instagram Reels**
#
# ### Brief Description and Match to Requirements
# `Instagram_Reels.csv` contains reel-level records with strong video-centric attributes (`views`, `video_play_count`, `length`, `audio_url`) plus engagement (`likes`, `num_comments`) and account context (`followers`, `following`). It is highly relevant for studying virality in short-form video content and complements static post data.

# %% [markdown]
# ### Profiling Steps (Description + Code + Interpretation)
# **Step A - Structural profile and key variables**
#
# ```python
# import pandas as pd
#
# df_reels = pd.read_csv("datasets/raw/Instagram_Reels.csv")
#
# print("Shape:", df_reels.shape)
# print(df_reels[["post_id", "date_posted", "likes", "num_comments", "views", "followers", "hashtags"]].head(3))
# ```
#
# **Interpretation:** Confirms availability of reel-specific outcome variables needed for virality evaluation.
#
# **Step B - Missingness and duplicates**
#
# ```python
# print("\nMissing values (top 15):\n", df_reels.isna().sum().sort_values(ascending=False).head(15))
# print("Duplicate post_id:", df_reels["post_id"].duplicated().sum())
# ```
#
# **Interpretation:** Reveals completeness risks (especially for follower-based normalization).
#
# **Step C - Value quality checks for numeric metrics**
#
# ```python
# num_cols = ["likes", "num_comments", "views", "followers", "video_play_count", "length"]
# for col in num_cols:
#     if col in df_reels.columns:
#         s = pd.to_numeric(df_reels[col], errors="coerce")
#         print(col, "| negatives:", (s < 0).sum(), "| zeros:", (s == 0).sum())
# ```
#
# **Interpretation:** Helps detect invalid values (e.g., negative likes) and practical edge cases (e.g., zero views).

# %% [markdown]
# ### Data Quality Discussion
# - **Positive criterion (Task relevance):** Includes direct exposure and engagement indicators (`views`, `likes`, `comments`) that are central to reel virality analysis.
# - **Problematic criterion (Data validity/completeness):** Presence of invalid negatives and/or missing follower information can distort normalized metrics such as engagement rate if not handled correctly.
#
# ### Concluding Suitability Statement
# This dataset is **suitable and important** for video-focused virality analysis, provided that invalid values are corrected to missing, normalization is done carefully, and missing follower/view cases are handled transparently.
#
# [Back to DS](#4-data-sources-prepare)

# %% [markdown]
# ## **DS4 - Instagram Datasets**
#
# ### Brief Description and Match to Requirements
# `Instagram_Datasets.csv` is primarily **comment-level** data (comment text, commenter, reply counts, tagged users in comments), linked to posts via `post_id` and `post_url`. It is less aligned with our main question because the analytical task focuses on **post characteristics vs viral status**, which is post-level rather than comment-thread level.

# %% [markdown]
# ### Profiling Steps (Description + Code + Interpretation)
# **Step A - Structural profile**
#
# ```python
# import pandas as pd
#
# df_comments = pd.read_csv("datasets/raw/Instagram_Datasets.csv")
#
# print("Shape:", df_comments.shape)
# print("Columns:", df_comments.columns.tolist())
# print(df_comments.head(3))
# ```
#
# **Interpretation:** Verifies that the unit of analysis is comments, not posts.
#
# **Step B - Missingness and duplicate checks**
#
# ```python
# print("\nMissing values (top 15):\n", df_comments.isna().sum().sort_values(ascending=False).head(15))
# print("Duplicate comment_id:", df_comments["comment_id"].duplicated().sum() if "comment_id" in df_comments.columns else "N/A")
# ```
#
# **Interpretation:** Assesses whether comment-level analysis is feasible and stable.
#
# **Step C - Granularity suitability check (post-level aggregation burden)**
#
# ```python
# if "post_id" in df_comments.columns:
#     print("Unique posts represented:", df_comments["post_id"].nunique())
#     print("Comments per post summary:\n", df_comments.groupby("post_id").size().describe())
# ```
#
# **Interpretation:** Shows how much aggregation is required before this dataset can support post-level modeling.

# %% [markdown]
# ### Data Quality Discussion
# - **Positive criterion (Textual depth):** Rich comment text and reply metadata can support sentiment/discourse studies or audience-reaction analysis.
# - **Problematic criterion (Granularity mismatch):** Core unit is comments, not posts, so it does not directly provide post-level characteristics or viral labels needed for the current analytical objective.
#
# ### Concluding Suitability Statement
# This dataset is **not recommended as a primary dataset** for the current task. It may be used as an optional enrichment source (e.g., aggregated sentiment per post), but only after substantial transformation and post-level linking.
#
# [Back to DS](#4-data-sources-prepare)

# %% [markdown]
# ## **DS5 - TikTok Posts**
#
# [Back to DS](#4-data-sources-prepare)

# %% [markdown]
# ## **DS6 - TikTok Texts**
#
# [Back to DS](#4-data-sources-prepare)

# %% [markdown]
# # Data Preparation (Posts + Reels + Analytics)
#
# Prepare high-quality datasets from:
# - `datasets/raw/Instagram_Posts.csv`
# - `datasets/raw/Instagram_Reels.csv`
# - `datasets/raw/Instagram_Analytics.csv`
#
# for analysis of post characteristics and virality.

# %% [markdown]
# ## Preparation Strategy
#
# We follow a rigorous data science preparation pipeline:
#
# 1. **Load raw data** from source files.
# 2. **Profile** data quality (schema, missingness, duplicates, invalid values).
# 3. **Structure** fields into consistent formats (e.g., datetime, hashtag list).
# 4. **Clean** invalid values without introducing bias (avoid replacing unknowns with zeros).
# 5. **Enrich** features useful for later analysis (`has_hashtags`, `hashtag_count`).
# 6. **Validate** post-clean quality with explicit checks.
# 7. **Export** prepared datasets for reproducible work.
#
# We prepare each dataset separately and will only create an optional "common-schema" combined table for compatible columns.

# %%
# Imports
import ast
from pathlib import Path

import numpy as np
import pandas as pd

# %%
# Ensure paths exist

# ROOT = /SC3021-SDAD-DS
ROOT = Path()

INSTAGRAM_POSTS_PATH = ROOT / "datasets" / "raw" / "Instagram_Posts.csv"
INSTAGRAM_REELS_PATH = ROOT / "datasets" / "raw" / "Instagram_Reels.csv"
OUTPUT_DIR = ROOT / "datasets" / "processed"

print("Posts path exists:", INSTAGRAM_POSTS_PATH.exists(), " | Path:", INSTAGRAM_POSTS_PATH)
print("Reels path exists:", INSTAGRAM_REELS_PATH.exists(), " | Path:", INSTAGRAM_REELS_PATH)
print("Output directory:", OUTPUT_DIR.resolve())
# Out:
# Posts path exists: True  | Path: datasets\raw\Instagram_Posts.csv
# Reels path exists: True  | Path: datasets\raw\Instagram_Reels.csv
# Output directory: D:\Z NTU\SC3021-SDAD-DS\datasets\processed

# %% [markdown]
# ## 1) Load Raw Data
#
# We first load both datasets exactly as provided, preserving raw values for profiling.

# %%
df_instagram_posts_raw = pd.read_csv(INSTAGRAM_POSTS_PATH)
df_instagram_reels_raw = pd.read_csv(INSTAGRAM_REELS_PATH)

print("Posts shape (Rows, Cols):", df_instagram_posts_raw.shape)
print("Reels shape (Rows, Cols):", df_instagram_reels_raw.shape)
# Out:
# Posts shape (Rows, Cols): (1000, 40)
# Reels shape (Rows, Cols): (1000, 27)

# %% [markdown]
# ## 2) Data Profiling Utilities
#
# Items to Check:
# - Data Types
# - Nulls/Blanks
# - Negatives/Zeros
# - Uniqueness/Duplicates
# - Value Distributions
# - Outliers/Anomalies
# - Pattern Analysis (Validate if data adheres to expected formats)
# - Standardisation (Check for inconsistent representations of the same data, such as "USA", "US", "America")

# %%
def check_data_types(df: pd.DataFrame) -> pd.DataFrame:
    """
    Inspect the inferred data type of every column.

    Returns a DataFrame with one row per column showing:
    - dtype       : pandas inferred dtype (e.g. int64, float64, object)
    - unique_count: number of distinct values including NaN
    - sample_value: first non-null value for a quick sanity-check
    """
    rows = []
    for col in df.columns:
        series = df[col]
        non_null = series.dropna()
        rows.append({
            "column": col,
            "dtype": str(series.dtype),
            "unique_count": int(series.nunique(dropna=False)),
            "sample_value": non_null.iloc[0] if not non_null.empty else None,
        })
    return pd.DataFrame(rows).set_index("column")


def check_nulls_blanks(df: pd.DataFrame) -> pd.DataFrame:
    """
    Identify missing values (NaN/None) and blank strings in every column.

    Returns a DataFrame sorted by null_pct descending with columns:
    - null_count  : number of NaN / None values
    - null_pct    : percentage of rows that are null
    - blank_count : number of empty-string ("") values (object columns only)
    - blank_pct   : percentage of rows that are blank strings
    """
    n = len(df)
    rows = []
    for col in df.columns:
        series = df[col]
        null_count = int(series.isna().sum())
        blank_count = int((series == "").sum()) if series.dtype == object else 0
        rows.append({
            "column": col,
            "null_count": null_count,
            "null_pct": round(null_count / n * 100, 2),
            "blank_count": blank_count,
            "blank_pct": round(blank_count / n * 100, 2),
        })
    return (
        pd.DataFrame(rows)
        .set_index("column")
        .sort_values("null_pct", ascending=False)
    )


def check_negatives_zeros(df: pd.DataFrame) -> pd.DataFrame:
    """
    Detect negative and zero values across all numeric columns.

    Negative values flag impossible entries (e.g. negative likes) that
    should be treated as invalid rather than coerced to zero.
    Zero values flag potential silent fill-ins where NaN would be
    more honest.

    Returns a DataFrame sorted by neg_count descending with columns:
    - neg_count  : number of values < 0
    - neg_pct    : percentage of rows that are negative
    - zero_count : number of values == 0
    - zero_pct   : percentage of rows that are zero
    """
    n = len(df)
    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    rows = []
    for col in numeric_cols:
        series = df[col]
        neg_count = int((series < 0).sum())
        zero_count = int((series == 0).sum())
        rows.append({
            "column": col,
            "neg_count": neg_count,
            "neg_pct": round(neg_count / n * 100, 2),
            "zero_count": zero_count,
            "zero_pct": round(zero_count / n * 100, 2),
        })
    return (
        pd.DataFrame(rows)
        .set_index("column")
        .sort_values("neg_count", ascending=False)
    )


def check_uniqueness_duplicates(
    df: pd.DataFrame, id_cols: list[str] | None = None
) -> dict:
    """
    Assess row-level and column-level uniqueness.

    Checks:
    - fully duplicated rows (every column identical)
    - duplicate values within each supplied id_col (should be 0 for keys)
    - unique-value ratio per column (low ratio signals near-constant columns)

    Returns a dict with keys:
    - 'full_duplicate_rows' : int count of fully duplicated rows
    - 'id_duplicates'       : {col: duplicate_count} for each id_col found
    - 'uniqueness_ratio'    : DataFrame of unique_count and unique_pct per column
    """
    result = {}
    result["full_duplicate_rows"] = int(df.duplicated().sum())

    id_duplicates = {}
    for col in (id_cols or []):
        if col in df.columns:
            id_duplicates[col] = int(df[col].duplicated().sum())
    result["id_duplicates"] = id_duplicates

    n = len(df)
    rows = []
    for col in df.columns:
        u = int(df[col].nunique(dropna=False))
        rows.append({"column": col, "unique_count": u, "unique_pct": round(u / n * 100, 2)})
    result["uniqueness_ratio"] = pd.DataFrame(rows).set_index("column")

    return result


def check_value_distributions(df: pd.DataFrame, top_n: int = 10) -> dict:
    """
    Summarise how values are distributed across columns.

    For numeric columns : returns descriptive statistics
    (count, mean, std, min, quartiles, max) via describe().
    For categorical/object columns : returns the top_n most
    frequent values and their counts via value_counts().

    Returns a dict with keys:
    - 'numeric_summary'  : pd.DataFrame (transposed describe)
    - 'categorical_top'  : {col: pd.Series of top_n value counts}
    """
    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    cat_cols = df.select_dtypes(include=["object", "category", "bool"]).columns.tolist()

    numeric_summary = df[numeric_cols].describe().T if numeric_cols else pd.DataFrame()

    categorical_top = {}
    for col in cat_cols:
        categorical_top[col] = df[col].value_counts(dropna=False).head(top_n)

    return {"numeric_summary": numeric_summary, "categorical_top": categorical_top}


def check_outliers_anomalies(
    df: pd.DataFrame, method: str = "iqr", z_thresh: float = 3.0
) -> pd.DataFrame:
    """
    Detect statistical outliers in numeric columns.

    Two detection methods are supported:
    - 'iqr'    : flags values outside Q1 - 1.5*IQR or Q3 + 1.5*IQR (Tukey fences)
    - 'zscore' : flags values whose absolute z-score exceeds z_thresh

    Returns a DataFrame sorted by outlier_count descending with columns:
    - outlier_count : number of flagged values
    - outlier_pct   : percentage of rows flagged as outliers
    """
    n = len(df)
    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    rows = []
    for col in numeric_cols:
        series = df[col].dropna()
        if method == "iqr":
            q1, q3 = series.quantile(0.25), series.quantile(0.75)
            iqr = q3 - q1
            mask = (df[col] < q1 - 1.5 * iqr) | (df[col] > q3 + 1.5 * iqr)
        else:
            mean, std = series.mean(), series.std()
            mask = (
                ((df[col] - mean).abs() / std) > z_thresh
                if std > 0
                else pd.Series(False, index=df.index)
            )
        outlier_count = int(mask.sum())
        rows.append({
            "column": col,
            "outlier_count": outlier_count,
            "outlier_pct": round(outlier_count / n * 100, 2),
        })
    return (
        pd.DataFrame(rows)
        .set_index("column")
        .sort_values("outlier_count", ascending=False)
    )


def check_pattern_analysis(
    df: pd.DataFrame, patterns: dict[str, str] | None = None
) -> pd.DataFrame:
    """
    Validate that string column values conform to expected regex patterns.

    The patterns argument maps column names to regex strings, e.g.:
        {"url": r"^https?://", "post_id": r"^\\d+$"}
    Only non-null values are tested; nulls are excluded from the denominator.
    If patterns is None, a sensible default is applied for common column
    names (url, post_id).

    Returns a DataFrame with columns:
    - pattern        : the regex used
    - match_count    : values that matched
    - mismatch_count : values that did not match
    - mismatch_pct   : percentage of non-null values that failed
    """
    default_patterns: dict[str, str] = {
        "url": r"^https?://",
        "post_id": r"^\d+$",
    }
    patterns = patterns or default_patterns

    rows = []
    for col, pattern in patterns.items():
        if col not in df.columns:
            continue
        non_null = df[col].dropna().astype(str)
        match_mask = non_null.str.match(pattern)
        match_count = int(match_mask.sum())
        mismatch_count = int((~match_mask).sum())
        total = len(non_null)
        rows.append({
            "column": col,
            "pattern": pattern,
            "match_count": match_count,
            "mismatch_count": mismatch_count,
            "mismatch_pct": round(mismatch_count / total * 100, 2) if total > 0 else 0.0,
        })
    return pd.DataFrame(rows).set_index("column") if rows else pd.DataFrame()


def check_standardisation(
    df: pd.DataFrame, cols: list[str] | None = None
) -> dict:
    """
    Identify inconsistent representations of the same value in string columns.

    Detects values that differ only by:
    - leading/trailing whitespace (e.g. " USA" vs "USA")
    - letter casing (e.g. "usa", "USA", "Usa")

    For each checked column, groups raw values by their stripped-and-lowercased
    form. Groups with more than one raw variant indicate a standardisation
    opportunity.

    Returns a dict mapping column name to a DataFrame of variant groups:
    - normalised_key : the canonical (stripped + lowercased) form
    - raw_variants   : list of differing raw strings that map to it
    An empty DataFrame means no inconsistencies were found for that column.
    """
    object_cols = df.select_dtypes(include=["object"]).columns.tolist()
    target_cols = [c for c in (cols or object_cols) if c in df.columns]

    result = {}
    for col in target_cols:
        series = df[col].dropna().astype(str)
        normalised = series.str.strip().str.lower()
        groups = (
            series.groupby(normalised)
            .apply(lambda g: sorted(g.unique().tolist()))
            .reset_index()
        )
        groups.columns = ["normalised_key", "raw_variants"]
        inconsistent = groups[groups["raw_variants"].apply(len) > 1].reset_index(drop=True)
        result[col] = inconsistent if not inconsistent.empty else pd.DataFrame()

    return result

# %%
# instagram_posts_profile_raw = profile_dataframe(df_instagram_posts_raw, "Posts (Raw)")
# instagram_reels_profile_raw = profile_dataframe(df_instagram_reels_raw, "Reels (Raw)")

# display_profile(instagram_posts_profile_raw)
# display_profile(instagram_reels_profile_raw)
# Out:
# ...
# Dataset: Posts (Raw)
# Shape: (1000, 40)
# Duplicate post_id: 0
# Duplicate url: 0
# --------------------------------------------------------------------------------
# Top missing columns:
#                        missing_count  missing_pct
# discovery_input                 1000        100.0
# has_handshake                   1000        100.0
# audio_url                        983         98.3
# video_play_count                 894         89.4
# coauthor_producers               893         89.3
# engagement_score_view            878         87.8
# product_type                     878         87.8
# video_view_count                 834         83.4
# videos                           821         82.1
# videos_duration                  769         76.9
# tagged_users                     730         73.0
# location                         724         72.4
# latest_comments                  417         41.7
# hashtags                         353         35.3
# ...

# %% [markdown]
# ## 3) Structuring + Cleaning Utilities
#
# Key principles:
# - Convert numeric fields with `errors='coerce'`.
# - Treat impossible negatives as invalid (`NaN`), not zero.
# - Keep true missingness as missing (to avoid biasing medians/rates).
# - Parse hashtag strings robustly into Python lists.

# %%
def parse_hashtags(value):
    """Convert hashtag field into a clean list of hashtag strings."""
    if pd.isna(value):
        return []

    if isinstance(value, list):
        raw_list = value
    elif isinstance(value, str):
        text = value.strip()
        if text == "" or text == "[]":
            return []
        try:
            parsed = ast.literal_eval(text)
            if isinstance(parsed, list):
                raw_list = parsed
            else:
                # Fallback: split a plain comma string if parsing is not list-like
                raw_list = [x.strip() for x in text.split(",") if x.strip()]
        except (ValueError, SyntaxError):
            raw_list = [x.strip() for x in text.split(",") if x.strip()]
    else:
        return []

    cleaned = []
    for tag in raw_list:
        if tag is None:
            continue
        tag = str(tag).strip()
        if tag == "":
            continue
        cleaned.append(tag)
    return cleaned


def clean_nonnegative_numeric(df: pd.DataFrame, cols: list[str]) -> pd.DataFrame:
    """Coerce selected columns to numeric and set negative values to NaN."""
    out = df.copy()
    for col in cols:
        if col in out.columns:
            out[col] = pd.to_numeric(out[col], errors="coerce")
            out.loc[out[col] < 0, col] = np.nan
    return out

# %% [markdown]
# ## 4) Prepare Posts Dataset (Separate Flow)

# %%
posts = df_posts_raw.copy()
posts["source_type"] = "post"

# Datetime structuring
if "date_posted" in posts.columns:
    posts["date_posted"] = pd.to_datetime(posts["date_posted"], errors="coerce", utc=True)

# Deduplicate conservatively
if "post_id" in posts.columns:
    posts = posts.drop_duplicates(subset=["post_id"], keep="first")
elif "url" in posts.columns:
    posts = posts.drop_duplicates(subset=["url"], keep="first")

# Parse hashtags and engineer hashtag features
posts["hashtags_list"] = posts["hashtags"].apply(parse_hashtags) if "hashtags" in posts.columns else [[] for _ in range(len(posts))]
posts["has_hashtags"] = posts["hashtags_list"].apply(lambda x: len(x) > 0)
posts["hashtag_count"] = posts["hashtags_list"].apply(len)

# Clean core metrics (non-negative constraints)
posts = clean_nonnegative_numeric(posts, ["likes", "num_comments", "followers", "video_view_count", "video_play_count", "posts_count"])

# Track missingness flags for core metrics
for metric in ["likes", "num_comments"]:
    if metric in posts.columns:
        posts[f"{metric}_is_missing"] = posts[metric].isna()

print("Prepared posts shape:", posts.shape)
posts[["source_type", "post_id", "date_posted", "likes", "num_comments", "has_hashtags", "hashtag_count"]].head()

# %% [markdown]
# ## 5) Prepare Reels Dataset (Separate Flow)

# %%
reels = df_reels_raw.copy()
reels["source_type"] = "reel"

# Datetime structuring
if "date_posted" in reels.columns:
    reels["date_posted"] = pd.to_datetime(reels["date_posted"], errors="coerce", utc=True)

# Deduplicate conservatively
if "post_id" in reels.columns:
    reels = reels.drop_duplicates(subset=["post_id"], keep="first")
elif "url" in reels.columns:
    reels = reels.drop_duplicates(subset=["url"], keep="first")

# Parse hashtags and engineer hashtag features
reels["hashtags_list"] = reels["hashtags"].apply(parse_hashtags) if "hashtags" in reels.columns else [[] for _ in range(len(reels))]
reels["has_hashtags"] = reels["hashtags_list"].apply(lambda x: len(x) > 0)
reels["hashtag_count"] = reels["hashtags_list"].apply(len)

# Clean core metrics (non-negative constraints)
reels = clean_nonnegative_numeric(reels, ["likes", "num_comments", "views", "followers", "video_play_count", "following", "posts_count", "length"])

# Track missingness flags for core metrics
for metric in ["likes", "num_comments", "views", "followers"]:
    if metric in reels.columns:
        reels[f"{metric}_is_missing"] = reels[metric].isna()

print("Prepared reels shape:", reels.shape)
reels[["source_type", "post_id", "date_posted", "likes", "num_comments", "views", "followers", "has_hashtags", "hashtag_count"]].head()

# %% [markdown]
# ## 6) Post-Clean Validation
#
# We rerun quality checks after preparation to verify:
# - duplicate handling worked
# - impossible negative values were removed
# - core engineered fields exist and look reasonable

# %%
posts_profile_clean = profile_dataframe(posts, "Posts (Prepared)")
reels_profile_clean = profile_dataframe(reels, "Reels (Prepared)")

display_profile(posts_profile_clean)
display_profile(reels_profile_clean)

# %%
print("Posts hashtag feature sanity check:")
print(posts["has_hashtags"].value_counts(dropna=False))
print(posts["hashtag_count"].describe())

print("\nReels hashtag feature sanity check:")
print(reels["has_hashtags"].value_counts(dropna=False))
print(reels["hashtag_count"].describe())

# %% [markdown]
# ## 7) Optional Common-Schema Table (For Compatible Analyses Only)
#
# A combined table can be useful for analyses based on shared columns (e.g., hashtags vs likes/comments),
# but **should not** be used for metrics requiring Reel-only fields (`views`, `followers`) without careful handling.

# %%
common_columns = [
    "source_type",
    "post_id",
    "url",
    "user_posted",
    "date_posted",
    "hashtags_list",
    "has_hashtags",
    "hashtag_count",
    "likes",
    "num_comments",
    "views",
    "followers",
    "is_verified",
    "is_paid_partnership",
]

def select_existing_columns(df: pd.DataFrame, cols: list[str]) -> pd.DataFrame:
    existing = [c for c in cols if c in df.columns]
    missing = [c for c in cols if c not in df.columns]
    out = df[existing].copy()
    for m in missing:
        out[m] = np.nan
    return out[cols]

posts_common = select_existing_columns(posts, common_columns)
reels_common = select_existing_columns(reels, common_columns)
df_common = pd.concat([posts_common, reels_common], ignore_index=True)

print("Common-schema combined shape:", df_common.shape)
df_common.head()

# %% [markdown]
# ## 8) Export Prepared Outputs
#
# We export:
# - `posts_prepared.csv`
# - `reels_prepared.csv`
# - `combined_common_schema_prepared.csv` (optional shared schema)

# %%
posts_out = OUTPUT_DIR / "posts_prepared.csv"
reels_out = OUTPUT_DIR / "reels_prepared.csv"
common_out = OUTPUT_DIR / "combined_common_schema_prepared.csv"

posts.to_csv(posts_out, index=False)
reels.to_csv(reels_out, index=False)
df_common.to_csv(common_out, index=False)

print("Saved:", posts_out)
print("Saved:", reels_out)
print("Saved:", common_out)

# %% [markdown]
# ## 9) Data Preparation Summary (No Analysis Yet)
#
# Completed:
# - rigorous profiling for raw and cleaned data
# - robust structuring/parsing of hashtags
# - non-negative validation for engagement metrics
# - explicit separation of Posts and Reels preparation pipelines
# - reproducible exports for next-stage analysis/modeling
#
# Not included in this notebook:
# - statistical testing
# - EDA conclusions
# - predictive modeling
#
# Those should be done in a separate analysis notebook using these prepared outputs.
