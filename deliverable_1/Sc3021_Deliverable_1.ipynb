# %% [markdown]
# # **Clearly state the data science question your team aims to answer.**

# %% [markdown]
# What is the relationship between specific post characteristics and the likelihood of a post achieving viral status on Social Media?

# %% [markdown]
# # **Identify key terms and provide the definition.**

# %% [markdown]
# * Post characteristics
#     * We will examine multiple types of posts, but most of which should fall under videos and texts.
#     * Characteristics for videos include the duration, or even frame rate and video resolution if applicable.
#     * Characteristics for texts include text length and the sentiment(tone) of the score.
#     * Generic characteristics applicable to both formats include posting time (hour of day), day of week, number of hashtags, and engagement-related data such as likes, comments and shares.
#
# * Viral status
#     * We define a viral post as follows:
#         * Speed of outreach: It gains popularity very fast, with views, shares, or mentions growing in an exponentially rather than slowly over time.
#         * High visibility: It reaches a large audience relative to a normal post, and may appear beyond the post's original intended community.
#     * If there is no data that shows the rate of post spread, i.e. the various timings for the post's growth of the number of shares, likes and comments, then we will use a preset time frame or preset number of shares/likes/comments to determine its virality.
#
# * Social Media
#     * For now, we are looking at TikTok, Facebook and Instagram, which are in the top 5 of most popular social platforms ([Wikipedia - List of most popular social platforms](https://en.wikipedia.org/wiki/List_of_most_popular_social_platforms))

# %% [markdown]
# # **Ask**

# %% [markdown]
# * **Problem to be solved:** Identify the key factors that contribute to the virality of a social media post.
#
# * **Underlying kind of problem:**  Predictive task to estimate post virality based on different post characteristics.
#
# * **Stackholders expectations:** Actionable insights that can aid in the creation of posts with a higher likelihood of being viral.
#
# * **Goal of analysis:** Identifying key post characteristics that significantly influences post virality may guide the definition of features and content for a post.
#
# * **Relevance to stackholders:** Enable stakeholders to strategically incorporate high-impact elements into their posts to increase the probability of making it viral.

# %% [markdown]
# # **Hypothesis Evaluation**

# %% [markdown]
# * **Null Hypothesis (H₀)**
#     * Post characteristics have no statistically significant effect on whether a post achieves viral status.
#
# * **Alternative Hypothesis (H₁)**
#     * At least one post characteristic has a statistically significant effect on whether a post achieves viral status.

# %% [markdown]
# # **Discuss the data requirements, i.e., what data is needed to address the problem.**

# %% [markdown]
# **1. Post Metadata**
# * Platform (e.g., Facebook/Meta, Instagram, Twitter/X, TikTok)
# * Date and time of posting
# * Day of week
# * Account
# * Number of followers at posting time

# %% [markdown]
# **2. Engagement Metrics**
# * Number of likes/reactions
# * Number of shares/retweets
# * Number of comments
# * Reach / impressions (if available)
# * Engagement rate (engagement ÷ followers)
# * Growth rate of engagement (e.g., engagement in first 1–24 hours) (if available)

# %% [markdown]
# **3. Content Characteristics**
# * Content Type
#     * Text-only, image, video etc
#     * Video length
#     * Text length
#     * Image count
# * Textual Features
#     * Caption length
#     * Hashtag count
#     * Mentions/tags
#     * Presence of emojis
#     * Sentiment score (positive / negative / neutral)
#     * Readability score
# * Visual Features (if available)
#     * Colorfulness / brightness
#     * Presence of faces or people
#     * Thumbnail quality (for videos)
# * Audio information (if available)
#     * Sound effects

# %% [markdown]
# **4. Others**
# * Topic category of post
# * Account used to post

# %% [markdown]
# ## DS1

# %% [markdown]
# [Facebook Text Classification (DS1) - Facebook_data_txt.csv](https://www.kaggle.com/datasets/kalashnikov1405/facebook-text-classification)

# %% [markdown]
# The dataset contains Facebook post data, in particular text classification.
#
# (Definition of text classification:
# It is a labeled collection of text data (sentences or documents) paired with predefined categories, used to train machine learning models to automatically categorize future, unseen text.)
#
# Strengths:
# * Has many useful attributes that directly measures how viral a post is as well as the post's corresponding properties. For example, the timestamp, engagement metrics and sentiment will be helpful here.
# * There may be potential for modelling of content popularity for prediction by using the likes, comments, shares data.
# * Useful to identify text to be used in posts that can give the most chance of making it viral.
#
# Weaknesses:
# * Does not have any information related to videos, as it only focuses on text-based media.

# %%
import pandas as pd

# %%
df = pd.read_csv('Facebook_data_txt.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   post_id    5000 non-null   int64
#  1   timestamp  5000 non-null   object
#  2   text       5000 non-null   object
#  3   category   5000 non-null   object
#  4   sentiment  5000 non-null   object
#  5   language   5000 non-null   object
#  6   has_link   5000 non-null   int64
#  7   likes      5000 non-null   int64
#  8   comments   5000 non-null   int64
#  9   shares     5000 non-null   int64
#  10  is_spam    5000 non-null   int64
# dtypes: int64(6), object(5)
# memory usage: 429.8+ KB

# %%
# change the by to likes,comments,shares etc
df.sort_values(by='likes', ascending=False).head(10)
# Out:
#       post_id            timestamp  \
# 1431     3278  2023-07-15 04:05:00
# 1137     2396  2024-02-17 16:59:00
# 786      3928  2024-08-05 07:36:00
# 2615     1550  2023-12-25 12:10:00
# 2529     4604  2023-09-01 21:02:00
# 1016      100  2024-08-26 05:24:00
# 3817     4141  2025-04-13 19:18:00
# 1323      858  2023-07-30 12:42:00
# 2880     2346  2023-05-20 08:09:00
# 2673     4083  2023-08-15 09:19:00
#
#                                                    text   category sentiment  \
# 1431                Friend: ‘We should work out.’ Us: 🎉  meme_joke  positive
# 1137  When you open the fridge and forget why you ca...  meme_joke  positive
# 786                 Friend: ‘We should work out.’ Us: 🔥  meme_joke  positive
# 2615                        POV: You at 8am meetings 🎉🎉  meme_joke  positive
# 2529  When you open the fridge and forget why you ca...  meme_joke  positive
# 1016            Me: I’ll sleep early. Also me at 3am: 😀  meme_joke  positive
# ...

# %%
df.describe(include="all")
# Out:
#             post_id            timestamp  \
# count   5000.000000                 5000
# unique          NaN                 4988
# top             NaN  2023-07-04 14:07:00
# freq            NaN                    2
# mean    2500.500000                  NaN
# std     1443.520003                  NaN
# min        1.000000                  NaN
# 25%     1250.750000                  NaN
# 50%     2500.500000                  NaN
# 75%     3750.250000                  NaN
# max     5000.000000                  NaN
#
#                                                      text         category  \
# count                                                5000             5000
# unique                                               1639               10
# top     Debate tonight on privacy law. What are your t...  personal_update
# freq                                                   32              985
# mean                                                  NaN              NaN
# ...

# %% [markdown]
# ## DS2

# %% [markdown]
# [Facebook posts dataset Bright Data (DS2) - facebook-posts-by-profile.csv](https://github.com/luminati-io/Facebook-dataset-samples/blob/main/facebook-posts-by-profile.csv)

# %% [markdown]
# The dataset is very comprehensive: It covers a wide area of content like posts, reels, events and comments. Hashtags and engagement metrics can be analyzed. We can also examine user interactions like using likes and replies to improve virality.
#
#
# Strengths:
# * Contains many useful attributes for further analysis
# * Has multiple post formats
# * Has post date and specific time so we can see the time of day effects for a post
# * Since I believe its part of the official dataset, this data should be comprehensive and useful
#
# Weaknesses:
# * Still lacks video duration and audio information, so we cannot fully study what makes a video viral
# * Has quite a lot of null attributes, and date format needs to be standardised, meaning needs some data processing

# %%
df = pd.read_csv('facebook-posts-by-profile.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   url                    1000 non-null   object
#  1   post_id                1000 non-null   int64
#  2   user_url               1000 non-null   object
#  3   user_username_raw      1000 non-null   object
#  4   content                984 non-null    object
#  5   date_posted            1000 non-null   object
#  6   hashtags               984 non-null    object
#  7   num_comments           1000 non-null   int64
#  8   num_shares             1000 non-null   int64
#  9   num_likes_type         988 non-null    object
#  10  page_name              1000 non-null   object
#  11  page_intro             0 non-null      float64
#  12  page_category          0 non-null      float64
#  13  page_logo              1000 non-null   object
# ...

# %%
df.describe()
# Out:
#             post_id  num_comments    num_shares  page_intro  page_category  \
# count  1.000000e+03   1000.000000   1000.000000         0.0            0.0
# mean   4.381055e+15    987.842000    897.273000         NaN            NaN
# std    3.051308e+15   2153.390746   2498.139281         NaN            NaN
# min    1.270469e+14      0.000000      0.000000         NaN            NaN
# 25%    1.029286e+15     82.500000     40.750000         NaN            NaN
# 50%    7.072014e+15    301.000000    179.000000         NaN            NaN
# 75%    7.139208e+15    958.000000    704.250000         NaN            NaN
# max    1.016096e+16  23055.000000  35082.000000         NaN            NaN
#
#        page_external_website    page_likes  page_followers  other_posts_url  \
# count                    0.0  9.500000e+02    1.000000e+03              0.0
# mean                     NaN  1.941064e+08    2.120672e+08              NaN
# ...

# %% [markdown]
# ## DS3

# %% [markdown]
# [Facebook Metrics Data (DS3) - Facebook Metrics of Cosmetic Brand.csv](https://www.kaggle.com/datasets/dileeppatchaone/facebook-metrics-dataset-of-cosmetic-brand)

# %% [markdown]
# This dataset comes from a cosmetics brand page and contains performance metrics for Facebook posts published over a year. It has no null values and includes about 500 posts with various engagement and metadata metrics, basically the usual likes, shares and comments etc.
#
# Strengths:
# * Also relevant to engagement virality analysis.
# * Has temporal data as well
# * Has a lifetime post data that might be helpful
#
# Weaknesses:
# * Not sure about its usefulness / relevance to the overarching theme which is that this is solely about cosmetics, and maybe our topic is about entertainment?
# * Also does not have multimedia data
# * Small sample of around 500 posts

# %%
df = pd.read_csv('Facebook Metrics of Cosmetic Brand.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 20 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Unnamed: 0                                                           500 non-null    int64
#  1   Page total likes                                                     500 non-null    int64
#  2   Type                                                                 500 non-null    object
#  3   Category                                                             500 non-null    int64
#  4   Post Month                                                           500 non-null    int64
#  5   Post Weekday                                                         500 non-null    int64
#  6   Post Hour                                                            500 non-null    int64
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  Page total likes    Category  Post Month  Post Weekday  \
# count  500.000000        500.000000  500.000000  500.000000    500.000000
# mean   249.500000     123194.176000    1.880000    7.038000      4.150000
# std    144.481833      16272.813214    0.852675    3.307936      2.030701
# min      0.000000      81370.000000    1.000000    1.000000      1.000000
# 25%    124.750000     112676.000000    1.000000    4.000000      2.000000
# 50%    249.500000     129600.000000    2.000000    7.000000      4.000000
# 75%    374.250000     136393.000000    3.000000   10.000000      6.000000
# max    499.000000     139441.000000    3.000000   12.000000      7.000000
#
#         Post Hour        Paid  Lifetime Post Total Reach  \
# count  500.000000  499.000000                  500.00000
# mean     7.840000    0.278557                13903.36000
# std      4.368589    0.448739                22740.78789
# min      1.000000    0.000000                  238.00000
# ...

# %% [markdown]
# # **DS4**
#
# Instagram Post dataset (DS1) - [Instagram-Posts.csv](https://brightdata.com/cp/datasets/browse/gd_lk5ns7kz21pck8jpis?id=hl_6c69a494)
#
# The dataset contains Instagram post data
#
#
# Strengths:
#
#
# *   Contains many useful post characteristics information. Including video duration, post content, hashtag, description,etc
# *   Contains virality measuring performance metrics (likes, shares, comments, etc)
# *   Linkable to comments via post_id for richer engagement.
#
#
#
#
# Weakness
#
#
# *   Data quality issues like negative likes values and extreme outliers

# %%
import pandas as pd
df = pd.read_csv('Instagram - Posts.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   url                    1000 non-null   object
#  1   user_posted            1000 non-null   object
#  2   description            956 non-null    object
#  3   hashtags               647 non-null    object
#  4   num_comments           1000 non-null   int64
#  5   date_posted            1000 non-null   object
#  6   likes                  888 non-null    float64
#  7   photos                 1000 non-null   object
#  8   videos                 179 non-null    object
#  9   location               276 non-null    object
#  10  latest_comments        583 non-null    object
#  11  post_id                1000 non-null   int64
#  12  discovery_input        0 non-null      float64
#  13  has_handshake          0 non-null      float64
# ...

# %%
df.sort_values(by='likes', ascending=False).head(10)
# Out:
#                                          url     user_posted  \
# 337  https://www.instagram.com/p/B-cRmb0o4aB          natgeo
# 627  https://www.instagram.com/p/CpNAFPwvBM-       folkative
# 412  https://www.instagram.com/p/C660WGGt_wD              f1
# 156  https://www.instagram.com/p/C70jImKS6BE     dilsepaneer
# 514  https://www.instagram.com/p/DNdKANzS4jr     ravisagar88
# 141  https://www.instagram.com/p/Bgs2JIFnnFO   dilettaleotta
# 96   https://www.instagram.com/p/DJZxxi8OHf0  amybethmcnulty
# 14   https://www.instagram.com/p/C58N0aMLHq0   premierleague
# 57   https://www.instagram.com/p/DLQkzuGOgw-   somosinvictos
# 678  https://www.instagram.com/p/DPJeg10D1JR          aajtak
#
#                                            description  \
# 337  Photo by @estherhorvath, Caption by @dzalcman ...
# 627  A new regulation for SMA and SMK students in K...
# 412  Michael’s first pole for Ferrari… and of cours...
# 156  Public Mein Nhi Dekh Sakte, Dosto Ki Bheji Ree...
# ...

# %%
df.describe(include="all")
# Out:
#                                             url             user_posted  \
# count                                      1000                    1000
# unique                                     1000                     994
# top     https://www.instagram.com/p/DD9dlUXTvTf  stratfordinternational
# freq                                          1                       2
# mean                                        NaN                     NaN
# std                                         NaN                     NaN
# min                                         NaN                     NaN
# 25%                                         NaN                     NaN
# 50%                                         NaN                     NaN
# 75%                                         NaN                     NaN
# max                                         NaN                     NaN
#
#                                               description  \
# ...

# %% [markdown]
# # **DS5**
#
# Instagram Reel dataset (DS2) - [Instagram-Reels.csv](https://brightdata.com/cp/datasets/browse/gd_lyclm20il4r5helnj?id=hl_6c69a494)
#
# Strengths:
#
# * Directly supports video-specific analysis with complete length (duration in seconds, mean 60s, no missing values) and strong engagement metrics like views (mean ~73k, up to 25M) and video_play_count.
# ​
#
# * Full coverage of core fields like date_posted, likes, num_comments, enabling easy extraction of posting time and hashtag counts (from hashtags, 65.6% non-null).
# ​
#
# * Includes creator context (followers, is_verified) for normalizing virality by audience size.
# ​
#
# Weaknesses:
#
# * High missingness in followers (48.1%) and posts_count (48.1%), limiting audience-adjusted models unless imputed.
# ​
#
# * Data quality issues like negative likes values and extreme outliers (e.g., views std ~826k), requiring cleaning and log-transformation.
# ​
#
# * No explicit "trending audio" flag; audio_url needs frequency-based proxy.

# %%
df = pd.read_csv('Instagram - Reels.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   url                  1000 non-null   object
#  1   user_posted          1000 non-null   object
#  2   description          956 non-null    object
#  3   hashtags             656 non-null    object
#  4   num_comments         1000 non-null   int64
#  5   date_posted          1000 non-null   object
#  6   likes                1000 non-null   int64
#  7   views                1000 non-null   int64
#  8   video_play_count     984 non-null    float64
#  9   top_comments         1000 non-null   object
#  10  post_id              1000 non-null   object
#  11  thumbnail            1000 non-null   object
#  12  shortcode            1000 non-null   object
#  13  content_id           1000 non-null   object
#  14  product_type         1000 non-null   object
# ...

# %%
df.sort_values(by='likes', ascending=False).head(10)
# Out:
#                                              url      user_posted  \
# 899  https://www.instagram.com/reel/DH5tG4NP5Nu/    aarushbhola17
# 765  https://www.instagram.com/reel/COgeRQ1CF1u/      fcbarcelona
# 646  https://www.instagram.com/reel/BVNWakrDAQQ/           natgeo
# 713  https://www.instagram.com/reel/DHyBYjGNRM9/  dev.mishra_ak47
# 239  https://www.instagram.com/reel/C-e39tIPyeJ/     ashwilliams1
# 359  https://www.instagram.com/reel/DG-eT2zR8MU/  ateez_official_
# 295  https://www.instagram.com/reel/CnuuDLRANvt/          espnmma
# 170  https://www.instagram.com/reel/C-XkhoGINSq/    xiaomi.global
# 729  https://www.instagram.com/reel/C_Hi4Mmt_Ia/     tianasari874
# 251  https://www.instagram.com/reel/CQvi7fiFH1o/        snoopdogg
#
#                                            description  \
# 899                                                🥰🥰🥰
# 765           🎯 Free kick GOLAZO! 🚀 \n\n💙❤️ @fcbfemeni
# 646  Video by @renan_ozturk @davemossop // A time-l...
# ...

# %%
df.describe(include="all")
# Out:
#                                                 url user_posted description  \
# count                                          1000        1000         956
# unique                                         1000         995         955
# top     https://www.instagram.com/reel/C7ULNWMMqUy/    jaat_nia          ❤️
# freq                                              1           2           2
# mean                                            NaN         NaN         NaN
# std                                             NaN         NaN         NaN
# min                                             NaN         NaN         NaN
# 25%                                             NaN         NaN         NaN
# 50%                                             NaN         NaN         NaN
# 75%                                             NaN         NaN         NaN
# max                                             NaN         NaN         NaN
#
# ...

# %% [markdown]
# # **DS6**
#
# Instagram generic dataset (DS3) - [Instagram-datasets.csv](https://github.com/luminati-io/Social-media-dataset-samples/blob/main/Instagram-datasets.csvhttps://github.com/luminati-io/Social-media-dataset-samples/blob/main/Instagram-datasets.csv)
#
# Strengths:
#
#
# *   Near-perfect completeness (0% missing in core columns like likes_number, replies_number, comment_date, post_id), ideal for aggregating comment engagement per post.
#
# *  Enables label enrichment (e.g., comments as virality signal) via post_id joins.
#
#
# * Low skew in metrics (e.g., likes_number mean 3.7), stable for summaries.
#
#
# Weaknesses:
#
# * Lacks post characteristics (no duration, hashtags, audio), only useful as an extension.
# ​
#
# * High missingness in hashtag_comment (99.4%) and tagged_users_in_comment (85.4%), limiting content analysis from comments.
# ​
#
# * Potential selection bias: only commented posts, skewing toward higher-engagement content.

# %%
df = pd.read_csv('Instagram-datasets.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   url                      1000 non-null   object
#  1   comment_user             1000 non-null   object
#  2   comment_user_url         1000 non-null   object
#  3   comment_date             1000 non-null   object
#  4   comment                  1000 non-null   object
#  5   likes_number             1000 non-null   int64
#  6   replies_number           1000 non-null   int64
#  7   replies                  998 non-null    object
#  8   hashtag_comment          6 non-null      object
#  9   tagged_users_in_comment  146 non-null    object
#  10  post_url                 1000 non-null   object
#  11  post_user                1000 non-null   object
#  12  comment_id               1000 non-null   int64
#  13  post_id                  1000 non-null   int64
# ...

# %%
df.sort_values(by='likes_number', ascending=False).head(10)
# Out:
#                                          url              comment_user  \
# 195    https://www.instagram.com/mahamfatima            ooo███zin███oo
# 802  https://www.instagram.com/motorsportcom              agg███kiu███
# 785  https://www.instagram.com/motorsportcom  ape███red███r_v█████████
# 794  https://www.instagram.com/motorsportcom                  ian███17
# 792  https://www.instagram.com/motorsportcom              com███ika███
# 913   https://www.instagram.com/adhouseplans        sav███ahs███cer███
# 938   https://www.instagram.com/nyxcosmetics             boo███oli███1
# 791  https://www.instagram.com/motorsportcom        for███aon███rlc███
# 786  https://www.instagram.com/motorsportcom              ___███2_2███
# 890   https://www.instagram.com/nyxcosmetics              gov███ame███
#
#                                      comment_user_url  \
# 195          https://www.instagram.com/oooamazingoooo
# 802              https://www.instagram.com/aggie.kiux
# ...

# %%
df.describe(include="all")
# Out:
#                                            url        comment_user  \
# count                                     1000                1000
# unique                                     273                 929
# top     https://www.instagram.com/nyxcosmetics  liv███nla███gas███
# freq                                        43                   6
# mean                                       NaN                 NaN
# std                                        NaN                 NaN
# min                                        NaN                 NaN
# 25%                                        NaN                 NaN
# 50%                                        NaN                 NaN
# 75%                                        NaN                 NaN
# max                                        NaN                 NaN
#
#                                  comment_user_url              comment_date  \
# count                                        1000                      1000
# ...

# %% [markdown]
# # **DS7**

# %% [markdown]
# [Shofo TikTok General (Small) – Extracted Posts Metadata (DS1)]
# File: `tiktok_posts.csv`

# %% [markdown]
# This dataset contains TikTok post-level metadata extracted from the Shofo TikTok General (Small) dataset.
#
# **Strengths:**
# - Contains temporal data (date/time posted), enabling analysis of posting time effects.
# - Includes video duration, which is directly relevant to short-form content performance.
# - Derived from a curated dataset source and structured for analysis.
#
# **Weaknesses:**
# - Does not include raw video content or audio features.
# - Some fields may require additional cleaning (e.g., timestamps, missing values).

# %%
import pandas as pd

tiktok_posts = pd.read_csv("tiktok_posts.csv")
tiktok_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57960 entries, 0 to 57959
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   video_id         57960 non-null  int64
#  1   creator          57960 non-null  object
#  2   web_url          57960 non-null  object
#  3   date_posted      57960 non-null  object
#  4   duration_sec     57960 non-null  float64
#  5   post_hour        57960 non-null  int64
#  6   post_day         57960 non-null  int64
#  7   is_ad            57960 non-null  bool
#  8   is_ai_generated  57960 non-null  bool
# dtypes: bool(2), float64(1), int64(3), object(3)
# memory usage: 3.2+ MB

# %%
posts = pd.read_csv("tiktok_posts.csv")
posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57960 entries, 0 to 57959
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   video_id         57960 non-null  int64
#  1   creator          57960 non-null  object
#  2   web_url          57960 non-null  object
#  3   date_posted      57960 non-null  object
#  4   duration_sec     57960 non-null  float64
#  5   post_hour        57960 non-null  int64
#  6   post_day         57960 non-null  int64
#  7   is_ad            57960 non-null  bool
#  8   is_ai_generated  57960 non-null  bool
# dtypes: bool(2), float64(1), int64(3), object(3)
# memory usage: 3.2+ MB

# %%
posts = pd.read_csv("tiktok_posts.csv")
posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57960 entries, 0 to 57959
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   video_id         57960 non-null  int64
#  1   creator          57960 non-null  object
#  2   web_url          57960 non-null  object
#  3   date_posted      57960 non-null  object
#  4   duration_sec     57960 non-null  float64
#  5   post_hour        57960 non-null  int64
#  6   post_day         57960 non-null  int64
#  7   is_ad            57960 non-null  bool
#  8   is_ai_generated  57960 non-null  bool
# dtypes: bool(2), float64(1), int64(3), object(3)
# memory usage: 3.2+ MB

# %%
posts.describe(include="all")
# Out:
#             video_id creator  \
# count   5.796000e+04   57960
# unique           NaN   41133
# top              NaN    espn
# freq             NaN     299
# mean    7.242002e+18     NaN
# std     2.349199e+17     NaN
# min     2.077112e+17     NaN
# 25%     7.049725e+18     NaN
# 50%     7.255774e+18     NaN
# 75%     7.452501e+18     NaN
# max     7.596256e+18     NaN
#
#                                                   web_url  \
# count                                               57960
# unique                                              57960
# top     https://www.tiktok.com/@kellyjunkjournals/vide...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# ...

# %% [markdown]
# # **DS8**

# %% [markdown]
# [Shofo TikTok General (Small) – engagement metrics (DS2) – tiktok_engagement_small.csv](https://huggingface.co/datasets/Shofo/shofo-tiktok-general-small)

# %% [markdown]
# This dataset contains engagement metrics for TikTok videos (e.g., play/view count, like count, comment count, share count).
# These fields are used to approximate virality.
#
# Strengths:
# * Contains direct engagement measures which are usable to define viral vs non-viral.
# * Allows ranking and threshold-based labeling (e.g., viral if play_count ≥ 1,000,000).
#
# Weaknesses:
# * “Virality” is not a universal definition; thresholds are arbitrary and should be justified.
# * Engagement distributions are typically very skewed (heavy-tailed), requiring careful interpretation.

# %%
eng = pd.read_csv("tiktok_engagement_small.csv")
eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   video_id    1500 non-null   int64
#  1   views       1500 non-null   int64
#  2   likes       1500 non-null   int64
#  3   shares      1500 non-null   int64
#  4   comments    1500 non-null   object
#  5   comments.1  1500 non-null   int64
#  6   viral       1500 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 82.2+ KB

# %%
eng.head()
# Out:
#               video_id     views    likes  shares  \
# 0  6816532490971352325  63775355  2838180   41197
# 1  7028648636569373958  11170118  1858449  119820
# 2  7448325474079509782  12580746  2038422  171523
# 3  7484195697500196103  11802998   656568   25968
# 4  7002430146313489669  46049047  4328002   45897
#
#                                             comments  comments.1  viral
# 0  [{"cid": "6817109813550809089", "text": "ye Ka...        3462      1
# 1  [{"cid": "7028668327887700782", "text": "TRAIL...       18234      1
# 2  [{"cid": "7450064475745534726", "text": "I wan...        4115      1
# 3  [{"cid": "7484943808595165960", "text": "\u101...        4116      1
# 4  [{"cid": "7003313186133836549", "text": "PUT M...       23380      1

# %%
eng.describe(include="all")
# Out:
#             video_id         views         likes        shares comments  \
# count   1.500000e+03  1.500000e+03  1.500000e+03  1.500000e+03     1500
# unique           NaN           NaN           NaN           NaN     1476
# top              NaN           NaN           NaN           NaN       []
# freq             NaN           NaN           NaN           NaN       25
# mean    7.231210e+18  2.683988e+07  3.075646e+06  1.600489e+05      NaN
# std     2.361382e+17  2.993694e+07  2.508836e+06  3.862209e+05      NaN
# min     6.655638e+18  8.100000e+01  1.000000e+00  0.000000e+00      NaN
# 25%     7.037300e+18  9.806592e+06  1.489674e+06  1.446775e+04      NaN
# 50%     7.241715e+18  1.861453e+07  2.512532e+06  5.380650e+04      NaN
# 75%     7.446487e+18  3.421150e+07  4.059367e+06  1.568095e+05      NaN
# max     7.596244e+18  4.160271e+08  2.341582e+07  9.597559e+06      NaN
#
#            comments.1        viral
# count     1500.000000  1500.000000
# ...

# %%
# quick check: what columns do we have?
eng.columns
# Out:
# Index(['video_id', 'views', 'likes', 'shares', 'comments', 'comments.1',
#        'viral'],
#       dtype='object')

# %%
# show top videos by play/view count (column name might be play_count)
# if your column is named differently, change it here after checking eng.columns
eng.sort_values(by="views", ascending=False).head(10)
# Out:
#                 video_id      views     likes   shares  \
# 282  7211568359798803717  416027059  13069793   134498
# 849  7293685461497777414  337083127   5554213    49471
# 472  7206834493833989383  249565433  15285115   643536
# 989  7436250163313790215  239700322  11514256  1971977
# 340  7527461232580775175  205407934   9859492   443721
# 62   7329861554189520161  202005910   3451794    37926
# 974  7538786096793079054  201039362  23415816  9597559
# 652  7203290581173275909  198126383  15088828   847452
# 201  7359245286134271237  186266310  11572182    57615
# 16   7325840538282822918  181591421   6577627   365581
#
#                                               comments  comments.1  viral
# 282  [{"cid": "7247732452964614954", "text": "yea c...       31247      1
# 849  [{"cid": "7300664360380203822", "text": "Who p...       29171      1
# 472  [{"cid": "7208550556783625003", "text": "There...       37486      1
# ...

# %% [markdown]
# # **DS9**

# %% [markdown]
# [Shofo TikTok General (Small) – text features (DS3) – tiktok_text.csv](https://huggingface.co/datasets/Shofo/shofo-tiktok-general-small)

# %% [markdown]
# This dataset contains text fields such as the caption/description and hashtags.
#
# Strengths:
# * Captions and hashtags can be quantified (e.g., hashtag count) and linked to engagement.
# * Useful for feature engineering without needing to download raw video.
#
# Weaknesses:
# * Text fields may be missing, noisy, or multilingual.
# * Hashtags may be stored as strings and require parsing/standardization.

# %%
txt = pd.read_csv("tiktok_text.csv")
txt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57960 entries, 0 to 57959
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       57960 non-null  int64
#  1   description    57549 non-null  object
#  2   hashtags       57960 non-null  object
#  3   hashtag_count  57960 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 1.8+ MB

# %%
txt.head()
# Out:
#               video_id                                        description  \
# 0  7350916080610643231  🙏🏼 #parati #fyp #carsoftiktok #greenscreen #xy...
# 1  7596163428251749663  todo que ver 🔥 🫦😍@YsraelBarajas #ysraelbarajas...
# 2  7313673452668439839  lindo detalle de gerberas 🥺 🌸 #parati #mexican...
# 3  7324533804658478378  omg cant believe i met you and i loved the shi...
# 4  7278870222382075167  #parati #foryou #viraltiktok #foryoupage❤️❤️ #...
#
#             hashtags  hashtag_count
# 0         ["parati"]              0
# 1  ["ysraelbarajas"]              0
# 2         ["parati"]              0
# 3         ["parati"]              0
# 4         ["parati"]              0

# %%
txt.describe(include="all")
# Out:
#             video_id description hashtags  hashtag_count
# count   5.796000e+04       57549    57960        57960.0
# unique           NaN       56194    13106            NaN
# top              NaN    #CapCut   ["fyp"]            NaN
# freq             NaN         158     7846            NaN
# mean    7.242002e+18         NaN      NaN            0.0
# std     2.349199e+17         NaN      NaN            0.0
# min     2.077112e+17         NaN      NaN            0.0
# 25%     7.049725e+18         NaN      NaN            0.0
# 50%     7.255774e+18         NaN      NaN            0.0
# 75%     7.452501e+18         NaN      NaN            0.0
# max     7.596256e+18         NaN      NaN            0.0

# %% [markdown]
# ## Merge datasets (DS7 + DS8 + DS9)
#
#
#
# We merge on video_id to combine post metadata, engagement metrics, and text fields into one analysis table.

# %%
df = posts.merge(eng, on="video_id", how="inner").merge(txt, on="video_id", how="left")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   video_id         1500 non-null   int64
#  1   creator          1500 non-null   object
#  2   web_url          1500 non-null   object
#  3   date_posted      1500 non-null   object
#  4   duration_sec     1500 non-null   float64
#  5   post_hour        1500 non-null   int64
#  6   post_day         1500 non-null   int64
#  7   is_ad            1500 non-null   bool
#  8   is_ai_generated  1500 non-null   bool
#  9   views            1500 non-null   int64
#  10  likes            1500 non-null   int64
#  11  shares           1500 non-null   int64
#  12  comments         1500 non-null   object
#  13  comments.1       1500 non-null   int64
#  14  viral            1500 non-null   int64
#  15  description      1491 non-null   object
#  16  hashtags         1500 non-null   object
# ...

# %%
df.head()
# Out:
#               video_id         creator  \
# 0  7596102576446147853     graciebmaee
# 1  7231295965381152043         l_j8125
# 2  7557815079488490807           sixfd
# 3  7269497009885678853          c9char
# 4  6998235538264214789  miriamfedakova
#
#                                              web_url  \
# 0  https://www.tiktok.com/@graciebmaee/video/7596...
# 1  https://www.tiktok.com/@l_j8125/video/72312959...
# 2  https://www.tiktok.com/@sixfd/video/7557815079...
# 3  https://www.tiktok.com/@c9char/video/726949700...
# 4  https://www.tiktok.com/@miriamfedakova/video/6...
#
#                  date_posted  duration_sec  post_hour  post_day  is_ad  \
# 0  2026-01-16 23:18:02+00:00        19.267         23         4  False
# 1  2023-05-09 21:21:43+00:00        34.165         21         1  False
# 2  2025-10-05 19:02:55+00:00        15.046         19         6  False
# 3  2023-08-20 20:01:10+00:00         5.718         20         6  False
# ...

# %% [markdown]
# ## Conclusion
#
# Overall, the Facebook, Instagram, and TikTok datasets together provide a suitable basis for analyzing how post characteristics influence the likelihood of achieving viral status on social media. While the available features vary slightly across platforms, all datasets include post-level metadata and engagement metrics that allow virality to be consistently approximated.The combined datasets support an analysis of key factors contributing to viral content.
